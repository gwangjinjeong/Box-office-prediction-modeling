# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
raw = pd.read_csv('csvutf.csv',skiprows=2)

# %%
rel = pd.read_csv('relmovie.csv',skiprows=2)

# %%
rel.shape
# Out:
# (8078, 18)

# %%
raw.shape
# Out:
# (5485, 18)

# %%
rel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8078 entries, 0 to 8077
# Data columns (total 18 columns):
# 순번        8078 non-null object
# 영화명       8078 non-null object
# 감독        7947 non-null object
# 제작사       2011 non-null object
# 수입사       6054 non-null object
# 배급사       8077 non-null object
# 개봉일       8078 non-null object
# 영화유형      8078 non-null object
# 영화형태      8077 non-null object
# 국적        8078 non-null object
# 전국스크린수    8078 non-null object
# 전국매출액     8078 non-null int64
# 전국관객수     8078 non-null object
# 서울매출액     8078 non-null int64
# 서울관객수     8078 non-null object
# 장르        8036 non-null object
# 등급        8077 non-null object
# 영화구분      8078 non-null object
# dtypes: int64(2), object(16)
# memory usage: 1.1+ MB

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5485 entries, 0 to 5484
# Data columns (total 18 columns):
# 순위        5484 non-null object
# 영화명       5483 non-null object
# 개봉일       2932 non-null object
# 매출액       5484 non-null object
# 매출액       5484 non-null object
# 누적매출액     5484 non-null object
# 관객수       5484 non-null object
# 누적관객수     5484 non-null object
# 스크린수      5484 non-null object
# 상영횟수      5484 non-null object
# 대표국적      5416 non-null object
# 국적        5410 non-null object
# 제작사       973 non-null object
# 배급사       2678 non-null object
# 등급        3051 non-null object
# 장르        5317 non-null object
# 감독        5027 non-null object
# 배우        3384 non-null object
# dtypes: object(18)
# memory usage: 771.4+ KB

# %%
raw2 = raw.drop(0)

# %%
rel.head(2)
# Out:
#    순번        영화명   감독                     제작사  수입사            배급사         개봉일  \
# 0  1          명량  김한민               (주)빅스톤픽쳐스  NaN      씨제이이앤엠(주)  2014-07-30
# 1  2   신과함께-죄와 벌  김용화  리얼라이즈픽쳐스(주),(주)덱스터스튜디오  NaN  롯데쇼핑㈜롯데엔터테인먼트  2017-12-20
#
#    영화유형 영화형태  국적  전국스크린수         전국매출액        전국관객수        서울매출액       서울관객수  \
# 0  개봉영화   장편  한국  1,587   135748398910  17,613,682   33121225810  4,163,666
# 1  개봉영화   장편  한국  1,912   115699634137  14,410,931   27530825087  3,346,172
#
#     장르        등급  영화구분
# 0   사극  15세이상관람가  상업영화
# 1  판타지  12세이상관람가  상업영화

# %%
raw2.head(2)
# Out:
#   순위  영화명         개봉일             매출액    매출액           누적매출액         관객수   \
# 1  1  베테랑  2015-08-05  105,169,264,250  3.1%  105,169,264,250  13,414,200
# 2  2   암살  2015-07-22   98,465,434,781  2.9%   98,465,434,781  12,706,388
#
#        누적관객수   스크린수     상영횟수  대표국적  국적              제작사        배급사        등급   \
# 1  13,414,200  1,115  199,240    한국  한국  (주)외유내강,(주)필름케이  씨제이이앤엠(주)  15세이상관람가
# 2  12,706,388  1,519  175,209    한국  한국         (주)케이퍼필름     (주)쇼박스  15세이상관람가
#
#       장르   감독                                                 배우
# 1  액션,드라마  류승완  황정민,유아인,유해진,오달수,장윤주,김시후,오대환,정웅인,정만식,송영창,진경,유인영...
# 2  액션,드라마  최동훈  전지현,이정재,하정우,오달수,조진웅,이경영,최덕문,김의성,박병은,김홍파,강용빈,홍성...

# %%
raw3=raw2.drop(['누적관객수 ','대표국적 ','제작사 ','순위','누적매출액 '], 1)

# %%
rel2= raw2.drop()
# 만약 신생감독이라면?, 신인배우라면?

# %%
#raw3
raw3.rename(columns={'영화명':'mname','개봉일':'date','매출액 ':'money','매출액':'share','관객수 ':'guest_num','스크린수 ':'scn_num','상영횟수 ':'show_num','국적 ':'country','배급사 ':'company','등급 ':'rating','장르 ':'genre','감독 ':'director','배우 ':'actor'}, inplace=True)

# %%
raw3
# Out:
#                             mname        date              money share  \
# 1                             베테랑  2015-08-05    105,169,264,250  3.1%
# 2                              암살  2015-07-22     98,465,434,781  2.9%
# 3                             부산행  2016-07-20     93,180,509,048  2.8%
# 4                            검사외전  2016-02-03     77,320,403,264  2.3%
# 5                   캡틴 아메리카: 시빌 워  2016-04-27     72,672,111,827  2.2%
# 6                              공조  2017-01-18     63,781,731,326  1.9%
# 7                            히말라야  2015-12-16     60,175,363,015  1.8%
# 8                              밀정  2016-09-07     61,270,079,831  1.8%
# 9                             마스터  2016-12-21     58,067,927,865  1.7%
# 10                             터널  2016-08-10     57,529,484,417  1.7%
# 11                           내부자들  2015-11-19     56,599,221,057  1.7%
# 12                         인천상륙작전  2016-07-27     55,105,606,303  1.6%
# ...

# %%
raw3.shape
# Out:
# (5484, 13)

# %%
rel

# %%
raw3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5484 entries, 1 to 5484
# Data columns (total 13 columns):
# mname        5483 non-null object
# date         2932 non-null object
# money        5484 non-null object
# share        5483 non-null object
# guest_num    5484 non-null object
# scn_num      5484 non-null object
# show_num     5484 non-null object
# country      5410 non-null object
# company      2678 non-null object
# rating       3051 non-null object
# genre        5317 non-null object
# director     5027 non-null object
# actor        3384 non-null object
# dtypes: object(13)
# memory usage: 599.8+ KB

# %%
raw3["date"].isnull()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
#        ...
# 970    False
# 971     True
# 972     True
# 973     True
# 974     True
# 975     True
# 976     True
# 977    False
# 978     True
# 979    False
# 980     True
# 981    False
# 982     True
# 983    False
# 984    False
# 985     True
# 986     True
# 987     True
# 988    False
# 989    False
# 990    False
# 991     True
# 992    False
# 993     True
# 994     True
# 995    False
# 996     True
# 997    False
# 998     True
# 999     True
# Name: date, Length: 999, dtype: bool

# %%
raw4= raw3.dropna(axis=0)

# %%
raw4
# Out:
#                    mname        date            money share   guest_num  \
# 1                    베테랑  2015-08-05  105,169,264,250  3.1%  13,414,200
# 2                     암살  2015-07-22   98,465,434,781  2.9%  12,706,388
# 3                    부산행  2016-07-20   93,180,509,048  2.8%  11,565,827
# 4                   검사외전  2016-02-03   77,320,403,264  2.3%   9,707,581
# 5          캡틴 아메리카: 시빌 워  2016-04-27   72,672,111,827  2.2%   8,677,249
# 6                     공조  2017-01-18   63,781,731,326  1.9%   7,817,446
# 7                   히말라야  2015-12-16   60,175,363,015  1.8%   7,759,761
# 8                     밀정  2016-09-07   61,270,079,831  1.8%   7,500,457
# 9                    마스터  2016-12-21   58,067,927,865  1.7%   7,150,541
# 10                    터널  2016-08-10   57,529,484,417  1.7%   7,120,508
# 11                  내부자들  2015-11-19   56,599,221,057  1.7%   7,072,507
# 12                인천상륙작전  2016-07-27   55,105,606,303  1.6%   7,050,475
# ...

# %%
raw4[raw4['mname'].str.contains('빅 히어로')]
# Out:
#       mname        date money share guest_num scn_num show_num country  \
# 5373  빅 히어로  2015-01-21     0  0.0%         0       1        2      미국
#
#              company rating         genre      director  \
# 5373  월트디즈니컴퍼니코리아(주)  전체관람가  애니메이션,액션,코미디  돈 홀,크리스 윌리암스
#
#                                                   actor
# 5373  라이언 포터,스콧 애짓,다니엘 헤니,제이미 정,T.J. 밀러,제네시스 로드리게스,데...

# %%
#raw3['country'].value_counts()
# Out:
# 미국                  407
# 한국                  315
# 일본                   76
# 영국                   20
# 독일                   17
# 프랑스                  16
# 기타                   15
# 미국,영국                11
# 중국                    9
# 영국,미국                 4
# 홍콩                    4
# 이탈리아                  4
# 프랑스,이탈리아              3
# 대만                    3
# 이탈리아,프랑스              3
# 미국,영국,프랑스             3
# 뉴질랜드,미국               3
# 캐나다,미국                2
# 미국,호주                 2
# 미국,칠레                 2
# 한국,중국                 2
# 스페인                   2
# 미국,프랑스                2
# 한국,미국                 2
# 스페인,이탈리아              2
# 브라질                   2
# 폴란드                   1
# 호주,미국                 1
# 영국,호주                 1
# 미국,벨기에,영국             1
#                    ...
# 인도                    1
# 미국,스페인                1
# 미국,독일                 1
# 영국,프랑스                1
# 중국,홍콩,미국              1
# 영국,호주,미국              1
# 한국,미국,호주              1
# ...

# %%
raw3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999 entries, 1 to 999
# Data columns (total 13 columns):
# mname        999 non-null object
# date         689 non-null object
# money        999 non-null object
# share        999 non-null object
# guest_num    999 non-null object
# scn_num      999 non-null object
# show_num     999 non-null object
# country      977 non-null object
# company      620 non-null object
# rating       721 non-null object
# genre        969 non-null object
# director     949 non-null object
# actor        859 non-null object
# dtypes: object(13)
# memory usage: 109.3+ KB

# %%
# 두개의 데이터를 비교해서
