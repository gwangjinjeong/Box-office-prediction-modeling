# %%
pip install selenium

# %%
# !apt install chromium-chromedriver

# %%
from selenium import webdriver

# %%
# set options to be headless, ..
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_azrgument('--disable-dev-shm-usage')
# open it, go to a website, and get results
wd = webdriver.Chrome('chromedriver',options=options)

# %%
wd.get("http://www.kobis.or.kr/kobis/business/stat/boxs/findFormerBoxOfficeList.do")
print(wd.page_source)  # results
# Out:
# <html lang="ko"><head>
# <meta charset="utf-8">
# <title>KOFIC 영화관 입장권 통합전산망 :: 역대 박스오피스</title>
# <!-- 공통 js/css -->
#
#
# <!--[if IE]>
# <script src="/kobis/web/comm/commjs/html5shiv.js"></script>
# <![endif]-->
#
#
#
# <!-- 기본 css -->
# <link rel="stylesheet" type="text/css" href="/kobis/web/comm/commcss/default.css">
# <link rel="stylesheet" type="text/css" href="/kobis/web/comm/commcss/jquery-ui-1.12.1.min.css">
# <link rel="stylesheet" type="text/css" href="/kobis/web/comm/commcss/common.css">
#
# <script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script src="http://cr.acecounter.com/Web/AceCounter_AW.js?gc=AB2A31560820885&amp;py=0&amp;gd=gtt6&amp;gp=8080&amp;up=NaPm_Ncisy&amp;rd=1584893381663"></script><script type="text/javascript" src="/kobis/web/comm/commjs/jquery-1.12.4.min.js"></script>
# <script type="text/javascript" src="/kobis/web/comm/commjs/jquery.dotdotdot.min.js"></script>
# ...

# %%
wd.find_element_by_xpath("""//*[@id="td_movie"]/span/a""").click()

# %%
print(wd.page_source)  # results
# Out:
# <html lang="ko"><head>
# <meta charset="utf-8">
# <title>KOFIC 영화관 입장권 통합전산망 :: 역대 박스오피스</title>
# <!-- 공통 js/css -->
#
#
# <!--[if IE]>
# <script src="/kobis/web/comm/commjs/html5shiv.js"></script>
# <![endif]-->
#
#
#
# <!-- 기본 css -->
# <link rel="stylesheet" type="text/css" href="/kobis/web/comm/commcss/default.css">
# <link rel="stylesheet" type="text/css" href="/kobis/web/comm/commcss/jquery-ui-1.12.1.min.css">
# <link rel="stylesheet" type="text/css" href="/kobis/web/comm/commcss/common.css">
#
# <script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script src="http://cr.acecounter.com/Web/AceCounter_AW.js?gc=AB2A31560820885&amp;py=0&amp;gd=gtt6&amp;gp=8080&amp;up=NaPm_Ncisy&amp;rd=1584893381663"></script><script type="text/javascript" src="/kobis/web/comm/commjs/jquery-1.12.4.min.js"></script>
# <script type="text/javascript" src="/kobis/web/comm/commjs/jquery.dotdotdot.min.js"></script>
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(wd.page_source, 'html.parser' )

# %%
tag_body = soup.find('tbody')

# %%
tag_body
# Out:
# <tbody>
# <tr id="tr_0">
# <td id="td_rank">
# 										1
# 									</td>
# <td class="tal" id="td_movie">
# <span class="ellip per90"><a href="#" onclick="mstView('movie','20129370');return false;" title="명량">명량</a></span>
# </td>
# <td id="td_openDt">
# 											2014-07-30
# 									</td>
# <td class="tar" id="td_salesAcc">
# 										135,757,221,810
# 									</td>
# <td class="tar" id="td_audiAcc">
# 										17,615,658
# 									</td>
# <td class="tar" id="td_scrnCnt">
# 										1,587
# 									</td>
# <td class="tar" id="td_showCnt">
# 										188,716
# 									</td>
# </tr>
# <tr class="even" id="tr_1">
# <td id="td_rank">
# 										2
# 									</td>
# <td class="tal" id="td_movie">
# <span class="ellip per90"><a href="#" onclick="mstView('movie','20182530');return false;" title="극한직업">극한직업</a></span>
# </td>
# <td id="td_openDt">
# 											2019-01-23
# 									</td>
# <td class="tar" id="td_salesAcc">
# 										139,652,045,516
# 									</td>
# ...

# %%
tag_body_top10 = self.soup.find('tbody', attrs={'id': 'tbody_0'})
tag_body_else = self.soup.findAll('tbody')

# %%
tr id="tr_121"
